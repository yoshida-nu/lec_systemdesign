# %% [markdown]
# # 第5回課題
# 以下の要件を満たすコードを作成しなさい．
#
# **＜要件＞**
# *  すでに入力されているコードは削除・変更しない
# *  コメントはすべて削除する
# *  以下のようなクラス `Dog` を定義する
# >*   `Animal`クラスを継承している
# >*   唯一のメソッドとして`speak`メソッドを持つ
# >*   `speak`メソッドは，スーパークラスの`speak`メソッドをオーバーライドしている
# *  「# ここにコードを記述」のある行にだけコードを追加で記述する
# *  新たに空行を作らない
# *  実行すると「The dog barks」と表示される
# *  指定した書式にノートブック名を変更する

# %%
class Animal:
    def speak(self):
        print('The animal makes a sound')

class # ここにコードを記述
    # ここにコードを記述
        print('The dog barks')

taro = Dog()
taro.speak() # The dog barks

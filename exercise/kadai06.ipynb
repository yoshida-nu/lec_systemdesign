# %% [markdown]
# # 第6回課題
# 以下の要件を満たすコードを作成しなさい．
#
# **＜要件＞**
# *  すでに入力されているコードは削除・変更しない
# *  コメントはすべて削除する
# *  `greet`関数をデコレートするデコレータ `before_after` を定義する
# ※ 　4行目のコードには，`func`を含める
# *  「# ここにコードを記述」のある行にだけコードを追加で記述する
# *  新たに空行を作らない
# *  指定した書式にノートブック名を変更する
# *  実行すると，以下の3行が表示される
# *  実行結果を表示した状態にして提出する
#
# **実行結果:**
# ```
# Before greeting
# Hello World!
# After greeting
# ```

# %%
def before_after(func):
    # ここにコードを記述
        print('Before greeting')
        # ここにコードを記述
        print('After greeting')
    return wrapper

# ここにコードを記述
def greet():
    print('Hello World!')

greet()

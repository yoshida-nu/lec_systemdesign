# %% [markdown]
# # 第4回課題
# 以下の要件を満たすコードを作成しなさい．
#
# **＜要件＞**
# *  すでに入力されているコードは削除・変更しない
# *  コメントはすべて削除する
# *  以下のようなクラス `Order` を定義する
# >*   インスタンス変数として単価を表す `price` が定義されている
# >*   インスタンス変数`price`の定義はコンストラクタで行う
# >*   クラス変数として消費税を表す `rate` が定義されている
# >*   クラス変数`rate`には，0.1（10%）を代入する
# >*   `calc` メソッドが定義されている
# >*   `calc` メソッドの戻り値を，引数（単価）に対する税込価格（単価×(1+rate)）とする
# *  「# ここにコードを記述」のある行にだけコードを追加で記述する
# *  新たに空行を作らない
# *  指定した書式にノートブック名を変更する

# %%
class Order:
    rate = # ここにコードを記述

    def __init__(self, a):
        # ここにコードを記述

    def # ここにコードを記述
        result = int(self.price * (1 + self.rate))
        return result

trans = Order(1000)
print(f'税込価格: {trans.calc()}円') # 税込価格: 1100円
